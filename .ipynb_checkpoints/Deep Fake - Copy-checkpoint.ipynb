# %%
import os
import pathlib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import shutil
import random
import tensorflow as tf
from tensorflow import keras
import tensorflow_hub as hub
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D, Activation, GlobalMaxPool2D, BatchNormalization
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import plot_model
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import splitfolders
# Out:
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# splits dataset it into three subfolders: train, val (validation), and test.

splitfolders.ratio(r"C:\Users\Ajay\Desktop\Inno_Projects\Pneumonia (TB) Identification\Dataset - Copy", output="output",
    seed=1337, ratio=(.75, .2, .05), group_prefix=None, move=False)
# Out:
# Copying files: 96 files [00:00, 121.75 files/s]

# %%
data_dir = pathlib.Path('output/')
train_dir = 'output/train'
val_dir = 'output/val'
test_dir = 'output/test'

# %%
class_name = np.array(sorted([item.name for item in data_dir.glob("*")]))
print(class_name)
# Out:
# ['test' 'train' 'val']

# %%
for dirpath, dirnames, filenames in os.walk('output'):
  print(f"{len(dirnames)} folder and {len(filenames)} images in {dirpath}")
# Out:
# 3 folder and 0 images in output
# 2 folder and 0 images in output\test
# 0 folder and 3 images in output\test\Normal
# 0 folder and 3 images in output\test\Tuberculosis
# 2 folder and 0 images in output\train
# 0 folder and 36 images in output\train\Normal
# 0 folder and 36 images in output\train\Tuberculosis
# 2 folder and 0 images in output\val
# 0 folder and 9 images in output\val\Normal
# 0 folder and 9 images in output\val\Tuberculosis

# %%
def view_random_image(target_dir, target_class):
    target_folder = target_dir + target_class
    random_image = random.sample(os.listdir(target_folder), 1)
    img = mpimg.imread(target_folder + "/" + random_image[0])
    plt.imshow(img)
    plt.title(target_class)
    plt.axis("off")
    
    print(f"Image Shape : {img.shape}")
    plt.show()

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='Tuberculosis')
# Out:
# Image Shape : (512, 512)

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='Normal')
# Out:
# Image Shape : (512, 512, 3)

# %%
# Sets the global random seed.
tf.random.set_seed(46)

# preprocess data
train_datagen = ImageDataGenerator(rescale=1/255.0,
                                   rotation_range=0.2,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   vertical_flip=True,
                                   horizontal_flip=True)
valid_datagen = ImageDataGenerator(rescale=1/255.0)
test_datagen = ImageDataGenerator(rescale=1/255.0)

# %%
train_data = train_datagen.flow_from_directory(train_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=True,
                                               seed=46)

valid_data = valid_datagen.flow_from_directory(val_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=False,
                                               seed=46)

test_data = test_datagen.flow_from_directory(test_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=False,
                                               seed=46)
# Out:
# Found 72 images belonging to 2 classes.
# Found 18 images belonging to 2 classes.
# Found 6 images belonging to 2 classes.

# %%
train_data.class_indices
# Out:
# {'Normal': 0, 'Tuberculosis': 1}

# %%
train_y=train_data.classes
val_y=valid_data.classes
test_y=test_data.classes

# %%
print("train_y.shape: ", train_y.shape)
print("val_y.shape: ", val_y.shape)
print("test_y.shape: ", test_y.shape)
# Out:
# train_y.shape:  (72,)
# val_y.shape:  (18,)
# test_y.shape:  (6,)

# %%
base_model = tf.keras.applications.DenseNet121(input_shape=(224, 224, 3),
                                                        include_top=False,
                                                        weights='imagenet')
base_model.trainable = False

# %%
global_average_layer = GlobalAveragePooling2D()
prediction_layer = Dense(2)
softmax = Activation('softmax')

inputs = Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)
x = Dropout(0.25)(x)
x = global_average_layer(x)
outputs = prediction_layer(x)
outputs = softmax(outputs)

model = Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet121 (Functional)        │ (None, 7, 7, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7, 7, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 1024)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │         2,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 2)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,039,554 (26.85 MB)
#  Trainable params: 2,050 (8.01 KB)
#  Non-trainable params: 7,037,504 (26.85 MB)

# %%
plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy'])

# train model
history = model.fit(train_data, epochs=20, validation_data=valid_data)
# Out:
# Epoch 1/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 21s 10s/step - accuracy: 0.5833 - loss: 0.7882 - val_accuracy: 0.5000 - val_loss: 0.8399
# Epoch 2/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5104 - loss: 0.7899 - val_accuracy: 0.5556 - val_loss: 0.6559
# Epoch 3/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.6574 - loss: 0.6197 - val_accuracy: 0.6111 - val_loss: 0.6441
# Epoch 4/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.5330 - loss: 0.7285 - val_accuracy: 0.6111 - val_loss: 0.6132
# Epoch 5/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.5341 - loss: 0.7271 - val_accuracy: 0.7778 - val_loss: 0.5481
# Epoch 6/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - accuracy: 0.7500 - loss: 0.5953 - val_accuracy: 0.8333 - val_loss: 0.5200
# Epoch 7/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 6s/step - accuracy: 0.7593 - loss: 0.5895 - val_accuracy: 0.6667 - val_loss: 0.5232
# Epoch 8/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.8102 - loss: 0.5122 - val_accuracy: 0.6111 - val_loss: 0.5340
# Epoch 9/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.7645 - loss: 0.5107 - val_accuracy: 0.6111 - val_loss: 0.5170
# Epoch 10/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 3s/step - accuracy: 0.7222 - loss: 0.5157 - val_accuracy: 0.7778 - val_loss: 0.4655
# Epoch 11/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.8368 - loss: 0.4728 - val_accuracy: 0.8889 - val_loss: 0.4014
# Epoch 12/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.8605 - loss: 0.4354 - val_accuracy: 0.9444 - val_loss: 0.3613
# Epoch 13/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 2s/step - accuracy: 0.8513 - loss: 0.4449 - val_accuracy: 0.9444 - val_loss: 0.3426
# Epoch 14/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step - accuracy: 0.8657 - loss: 0.4017 - val_accuracy: 0.9444 - val_loss: 0.3319
# Epoch 15/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.8368 - loss: 0.4190 - val_accuracy: 1.0000 - val_loss: 0.3125
# Epoch 16/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.9277 - loss: 0.3460 - val_accuracy: 0.9444 - val_loss: 0.2948
# Epoch 17/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.9091 - loss: 0.3690 - val_accuracy: 0.9444 - val_loss: 0.2927
# Epoch 18/20
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.9375 - loss: 0.3402

# %%
def plot_loss_curves(history):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(loss))

  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title("Loss Curves")
  plt.xlabel("Epochs")
  plt.legend()

  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title("Accuracy Curves")
  plt.xlabel("Epochs")
  plt.legend()

# %%
val_pred = model.predict(valid_data)
val_pred = val_pred.argmax(axis=1)
print(classification_report(val_pred, val_y))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        33
#            1       1.00      1.00      1.00        24
#
#     accuracy                           1.00        57
#    macro avg       1.00      1.00      1.00        57
# weighted avg       1.00      1.00      1.00        57

# %%
cfm_val = confusion_matrix(val_pred, val_y)
ax = sns.heatmap(cfm_val, annot=True, 
            cmap='Blues')

# Preparation for plotting confusion matrix
ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

# Display the visualization of the Confusion Matrix.
plt.show()

# %%
test_pred = model.predict(test_data)
test_pred = test_pred.argmax(axis=1)
print(classification_report(test_pred, test_y))
# Out:
# C:\Users\ajayk\anaconda3\envs\py310\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       1.00      1.00      1.00         6
#
#     accuracy                           1.00        15
#    macro avg       1.00      1.00      1.00        15
# weighted avg       1.00      1.00      1.00        15

# %%
cfm_test = confusion_matrix(test_pred, test_y)
ax = sns.heatmap(cfm_test, annot=True, 
            cmap='Blues')

# Preparation for plotting confusion matrix
ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

# Display the visualization of the Confusion Matrix.
plt.show()

# %%
model.save('my_model.keras')

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\ajayk\anaconda3\envs\py310\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ajayk\anaconda3\envs\py310\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the trained model
model = load_model('my_model.keras')

# Load the image
image_path = r"C:\Users\ajayk\Desktop\InnoProjects\SRIT\Driver Drowsiness detection using deep learning\Dataset\Drowsiness\s0001_00157_0_0_0_0_0_01.png"
image = image.load_img(image_path, target_size=(224, 224))

# Preprocess the image
img = np.array(image)
img = img / 255.0
img = img.reshape(1, 224, 224, 3)

# Predict the label
label = model.predict(img)

# Determine the predicted class
class_names = ['Active Driver', 'Drowsiness']
predicted_class_index = np.argmax(label)
predicted_class = class_names[predicted_class_index]

# Print the predicted class
print("Predicted Class:", predicted_class)

# Display the image with the predicted label
plt.imshow(image)
plt.title(predicted_class)
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Predicted Class: Drowsiness

# %%
import matplotlib.pyplot as plt
from keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the trained model
model = load_model('my_model.keras')

# Load the image
image_path = r"C:\Users\ajayk\Desktop\InnoProjects\SRIT\Driver Drowsiness detection using deep learning\Dataset\Active Driver\s0001_02379_0_0_1_0_0_01.png"
image = image.load_img(image_path, target_size=(224, 224))

# Preprocess the image
img = np.array(image)
img = img / 255.0
img = img.reshape(1, 224, 224, 3)

# Predict the label
label = model.predict(img)

# Determine the predicted class
class_names = ['Active Driver', 'Drowsiness']
predicted_class_index = np.argmax(label)
predicted_class = class_names[predicted_class_index]

# Print the predicted class
print("Predicted Class:", predicted_class)

# Display the image with the predicted label
plt.imshow(image)
plt.title(predicted_class)
plt.axis('off')
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000029748EE4A60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# Predicted Class: Active Driver

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image
from keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# Function to classify an image
def classify_image():
    # Load the trained model
    model = load_model('my_model.keras')
    
    # Open a dialog box to select an image file
    file_path = filedialog.askopenfilename(
        title="Select an Image File",
        filetypes=[("Image Files", "*.png;*.jpg;*.jpeg")]
    )
    
    if not file_path:
        print("No file selected.")
        return

    # Load the selected image and ensure it's in RGB mode
    img = Image.open(file_path).convert("RGB")
    img = img.resize((224, 224))  # Resize the image to match model input size

    # Convert image to numpy array and preprocess
    img_array = np.array(img)
    img_array = img_array / 255.0  # Normalize pixel values
    img_array = img_array.reshape(1, 224, 224, 3)

    # Predict the label
    label = model.predict(img_array)

    # Determine the predicted class
    class_names = ['Active Driver', 'Drowsiness']
    predicted_class_index = np.argmax(label)
    predicted_class = class_names[predicted_class_index]

    # Display the image with the predicted label
    plt.imshow(img)
    plt.title(predicted_class)
    plt.axis('off')
    plt.show()

# Create a Tkinter window
root = tk.Tk()
root.title("Drowsiness Detection Classifier")

# Create a button to trigger image classification
classify_button = tk.Button(root, text="Classify Image", command=classify_image)
classify_button.pack(pady=10)

# Run the Tkinter event loop
root.mainloop()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
import cv2
import numpy as np
from keras.models import load_model

# Load the trained model
model = load_model('my_model.keras')

# Define class-specific messages
class_messages = {
    0: "You are active.",
}

# Default message (if not active)
default_message = "Not Active"

# Function to preprocess the image for prediction
def preprocess_frame(frame):
    frame_resized = cv2.resize(frame, (224, 224))  # Resize to model input size
    frame_array = np.array(frame_resized, dtype="float32") / 255.0  # Normalize
    frame_array = np.expand_dims(frame_array, axis=0)  # Add batch dimension
    return frame_array

# Access the webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not access the webcam.")
else:
    print("Press 'q' to quit the application.")

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame. Exiting...")
        break

    # Get frame dimensions
    height, width, _ = frame.shape

    # Increase the size of the ROI
    roi_size = int(min(width, height) * 0.4)  # Square size is now 40% of the smaller dimension (increase this percentage)
    center_x, center_y = width // 2, height // 2
    roi_x1 = center_x - roi_size // 2
    roi_y1 = center_y - roi_size // 2
    roi_x2 = center_x + roi_size // 2
    roi_y2 = center_y + roi_size // 2

    # Draw the ROI rectangle on the frame
    cv2.rectangle(frame, (roi_x1, roi_y1), (roi_x2, roi_y2), (0, 255, 0), 2)

    # Extract the ROI for detection
    roi = frame[roi_y1:roi_y2, roi_x1:roi_x2]

    # Convert ROI to grayscale for Haar Cascade detection
    gray_roi = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)

    # Load Haar Cascade for eye detection
    eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

    # Detect eyes within the ROI
    eyes = eye_cascade.detectMultiScale(gray_roi, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    if len(eyes) == 0:
        # If no eyes are detected, display the default message ("Drowsy")
        cv2.putText(
            frame,
            default_message,  # Display "You are drowsy" message
            (10, 30),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (0, 0, 255),
            2
        )
    else:
        # Preprocess the ROI for classification
        preprocessed_roi = preprocess_frame(roi)

        # Debug: print shape of preprocessed ROI
        print("Preprocessed ROI shape:", preprocessed_roi.shape)

        # Predict the class (Active or Drowsy)
        predictions = model.predict(preprocessed_roi)
        predicted_class_index = np.argmax(predictions)

        # Set the message based on predicted class
        if predicted_class_index == 0:
            predicted_message = class_messages[0]  # Active
        else:
            predicted_message = default_message  # Drowsy

        # Display the result on the webcam feed
        cv2.putText(
            frame,
            predicted_message,
            (10, 30),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (0, 255, 0),
            2
        )

    # Show the webcam feed with ROI
    cv2.imshow("Drowsiness Detection", frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Press 'q' to quit the application.
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
